# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Fashion_Retail_Sales.csv')

# %%
df
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag                 4619.0
# 1                      4115          Tunic                 2456.0
# 2                      4019       Tank Top                 2102.0
# 3                      4097       Leggings                 3126.0
# 4                      3997         Wallet                 3003.0
# ...                     ...            ...                    ...
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 0       05-02-2023            NaN    Credit Card
# 1       11-07-2023            2.0    Credit Card
# ...

# %%
df.head()
# Out:
#    Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                   4018        Handbag                 4619.0    05-02-2023
# 1                   4115          Tunic                 2456.0    11-07-2023
# 2                   4019       Tank Top                 2102.0    23-03-2023
# 3                   4097       Leggings                 3126.0    15-03-2023
# 4                   3997         Wallet                 3003.0    27-11-2022
#
#    Review Rating Payment Method
# 0            NaN    Credit Card
# 1            2.0    Credit Card
# 2            4.1           Cash
# 3            3.2           Cash
# 4            4.7           Cash

# %%
df.tail()
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 3395    09-07-2023            2.7           Cash
# 3396    16-03-2023            2.5           Cash
# 3397    03-10-2022            2.4    Credit Card
# 3398    01-01-2023            1.8           Cash
# 3399    22-03-2023            1.4           Cash

# %%
df.sample(10)
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 3269                   3975       Leggings                   76.0
# 3029                   3967  Flannel Shirt                   99.0
# 1704                   4014       Tank Top                   99.0
# 2130                   4034          Scarf                   66.0
# 115                    3992       Cardigan                   42.0
# 2530                   4086        Loafers                    NaN
# 1652                   4089     Polo Shirt                    NaN
# 1202                   3988          Socks                  176.0
# 166                    4119          Pants                    NaN
# 975                    4010           Belt                  104.0
#
#      Date Purchase  Review Rating Payment Method
# 3269    03-07-2023            2.4    Credit Card
# 3029    03-02-2023            4.0           Cash
# 1704    02-10-2022            1.2           Cash
# ...

# %%
df.columns
# Out:
# Index(['Customer Reference ID', 'Item Purchased', 'Purchase Amount (USD)',
#        'Date Purchase', 'Review Rating', 'Payment Method'],
#       dtype='object')

# %%
df.shape
# Out:
# (3400, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer Reference ID  3400 non-null   int64
#  1   Item Purchased         3400 non-null   object
#  2   Purchase Amount (USD)  2750 non-null   float64
#  3   Date Purchase          3400 non-null   object
#  4   Review Rating          3076 non-null   float64
#  5   Payment Method         3400 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 159.5+ KB

# %%
df.describe()
# Out:
#        Customer Reference ID  Purchase Amount (USD)  Review Rating
# count            3400.000000            2750.000000    3076.000000
# mean             4039.660588             156.709818       2.999057
# std                48.122583             419.536669       1.156505
# min              3957.000000              10.000000       1.000000
# 25%              3997.000000              57.000000       2.000000
# 50%              4040.000000             110.000000       3.000000
# 75%              4081.000000             155.750000       4.000000
# max              4122.000000            4932.000000       5.000000

# %%
df.isnull().sum()
# Out:
# Customer Reference ID      0
# Item Purchased             0
# Purchase Amount (USD)    650
# Date Purchase              0
# Review Rating            324
# Payment Method             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Item Purchased'].value_counts()
# Out:
# Item Purchased
# Belt             90
# Skirt            88
# Shorts           87
# Pants            86
# T-shirt          82
# Tank Top         82
# Pajamas          81
# Loafers          76
# Camisole         76
# Hoodie           75
# Socks            73
# Kimono           73
# Wallet           73
# Poncho           73
# Blouse           73
# Handbag          72
# Cardigan         72
# Onesie           71
# Sneakers         71
# Vest             71
# Backpack         71
# Blazer           71
# Umbrella         70
# Raincoat         69
# Hat              68
# Trench Coat      68
# Sunglasses       67
# Coat             67
# Swimsuit         66
# Scarf            66
# Boots            65
# Romper           64
# Jacket           64
# Flannel Shirt    63
# Leggings         62
# Sweater          62
# Overalls         61
# Tunic            61
# Gloves           59
# Polo Shirt       59
# Trousers         58
# Jeans            58
# Slippers         58
# Tie              57
# ...

# %%
plt.figure(figsize=(14,14))
sns.countplot(df['Item Purchased'])
# Out:
# <Axes: xlabel='count', ylabel='Item Purchased'>

# %%
plt.figure(figsize=(14,14))
df['Item Purchased'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df,hue='Payment Method')

# %%
df['Item Purchased'].value_counts()
# Out:
# Item Purchased
# Belt             90
# Skirt            88
# Shorts           87
# Pants            86
# T-shirt          82
# Tank Top         82
# Pajamas          81
# Loafers          76
# Camisole         76
# Hoodie           75
# Socks            73
# Kimono           73
# Wallet           73
# Poncho           73
# Blouse           73
# Handbag          72
# Cardigan         72
# Onesie           71
# Sneakers         71
# Vest             71
# Backpack         71
# Blazer           71
# Umbrella         70
# Raincoat         69
# Hat              68
# Trench Coat      68
# Sunglasses       67
# Coat             67
# Swimsuit         66
# Scarf            66
# Boots            65
# Romper           64
# Jacket           64
# Flannel Shirt    63
# Leggings         62
# Sweater          62
# Overalls         61
# Tunic            61
# Gloves           59
# Polo Shirt       59
# Trousers         58
# Jeans            58
# Slippers         58
# Tie              57
# ...

# %%
df['Item Purchased'].unique()
# Out:
# array(['Handbag', 'Tunic', 'Tank Top', 'Leggings', 'Wallet', 'Onesie',
#        'Jacket', 'Trousers', 'Jeans', 'Loafers', 'Slippers', 'Bowtie',
#        'Pajamas', 'Trench Coat', 'Poncho', 'Gloves', 'Romper', 'T-shirt',
#        'Flip-Flops', 'Shorts', 'Blazer', 'Boots', 'Belt', 'Hoodie',
#        'Sweater', 'Blouse', 'Swimsuit', 'Kimono', 'Cardigan', 'Socks',
#        'Pants', 'Scarf', 'Backpack', 'Dress', 'Camisole', 'Sneakers',
#        'Flannel Shirt', 'Tie', 'Polo Shirt', 'Umbrella', 'Hat', 'Sun Hat',
#        'Overalls', 'Coat', 'Sunglasses', 'Vest', 'Sandals', 'Jumpsuit',
#        'Raincoat', 'Skirt'], dtype=object)

# %%
sns.boxplot(df['Purchase Amount (USD)'])
# Out:
# <Axes: ylabel='Purchase Amount (USD)'>

# %%
sns.boxplot(df['Review Rating'])
# Out:
# <Axes: ylabel='Review Rating'>

# %%
amt=df['Purchase Amount (USD)'].median()

# %%
amt
# Out:
# np.float64(110.0)

# %%
df['Pur']=df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].median())

# %%
sns.boxplot(df['Purchase Amount'])
# Out:
# <Axes: ylabel='Purchase Amount'>

# %%
df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].median(),inplace=True)
# Out:
# C:\Users\anime\AppData\Local\Temp\ipykernel_12264\79928416.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].median(),inplace=True)

# %%
df['Purchase Amount (USD)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Review Rating'].fillna(df['Review Rating'].mean()).round(1)
# Out:
# 0       3.0
# 1       2.0
# 2       4.1
# 3       3.2
# 4       4.7
#        ...
# 3395    2.7
# 3396    2.5
# 3397    2.4
# 3398    1.8
# 3399    1.4
# Name: Review Rating, Length: 3400, dtype: float64

# %%
df['Review Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
###

# %% [markdown]
# ### Lets Handle Outliers

# %% [markdown]
# df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].astype('float')

# %%
Q1=df['Purchase Amount (USD)'].quantile(0.25)
Q3=df['Purchase Amount (USD)'].quantile(0.75)

IQR=Q3-Q1
lower_fence=IQR-1.5*(Q1)
high_fence=IQR+1.5*(Q3)
outliers=df[(df['Purchase Amount (USD)']<lower_fence) | (df['Purchase Amount (USD)']>high_fence)]


print(outliers.shape[0])
# Out:
# 43

# %%
print(df[df['Purchase Amount (USD)']>high_fence])
# Out:
#     Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                    4018        Handbag                 4619.0    05-02-2023
# 1                    4115          Tunic                 2456.0    11-07-2023
# 2                    4019       Tank Top                 2102.0    23-03-2023
# 3                    4097       Leggings                 3126.0    15-03-2023
# 4                    3997         Wallet                 3003.0    27-11-2022
# 5                    4080         Onesie                 2914.0    11-12-2022
# 6                    4055         Jacket                 2571.0    08-07-2023
# 7                    3973       Trousers                 2419.0    10-11-2022
# 8                    4044          Jeans                 4771.0    19-05-2023
# 9                    4010        Loafers                 4233.0    11-06-2023
# 10                   4108       Slippers                 2356.0    19-03-2023
# ...

# %%
# if(df['Purchase Amount (USD)']>high_fence):
df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].clip(upper=high_fence)

# %%
count = (df['Purchase Amount'] > high_fence).sum()
print("Count:", count)
# Out:
# Count: 0

# %%
df['Purchase Amount (USD)'].dtype
# Out:
# dtype('float64')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
df['Item Purchased']=label.fit_transform(df['Item Purchased'])

# %%
df['Item Purchased']
# Out:
# 0       13
# 1       46
# 2       42
# 3       20
# 4       49
#         ..
# 3395    32
# 3396    34
# 3397    22
# 3398    30
# 3399     0
# Name: Item Purchased, Length: 3400, dtype: int64

# %%
df['Payment Method']
# Out:
# 0       Credit Card
# 1       Credit Card
# 2              Cash
# 3              Cash
# 4              Cash
#            ...
# 3395           Cash
# 3396           Cash
# 3397    Credit Card
# 3398           Cash
# 3399           Cash
# Name: Payment Method, Length: 3400, dtype: object

# %%
df['Payment Method']=label.fit_transform(df['Payment Method'])

# %%
df['Payment Method']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 3395    0
# 3396    0
# 3397    1
# 3398    0
# 3399    0
# Name: Payment Method, Length: 3400, dtype: int64

# %%
df
# Out:
#       Customer Reference ID  Item Purchased  Purchase Amount  Review Rating  \
# 0                      4018              13            295.0       2.999057
# 1                      4115              46            295.0       2.000000
# 2                      4019              42            295.0       4.100000
# 3                      4097              20            295.0       3.200000
# 4                      3997              49            295.0       4.700000
# ...                     ...             ...              ...            ...
# 3395                   4118              32             37.0       2.700000
# 3396                   4056              34            176.0       2.500000
# 3397                   3991              22            110.0       2.400000
# 3398                   4042              30            128.0       1.800000
# 3399                   4001               0            115.0       1.400000
#
#       Payment Method  Date  Month  Year
# ...

# %%
df.rename(columns={'Purchase Amount (USD)':'Purchase Amount'},inplace=True)

# %%
df
# Out:
#       Customer Reference ID  Item Purchased  Purchase Amount Date Purchase  \
# 0                      4018              13            295.0    05-02-2023
# 1                      4115              46            295.0    11-07-2023
# 2                      4019              42            295.0    23-03-2023
# 3                      4097              20            295.0    15-03-2023
# 4                      3997              49            295.0    27-11-2022
# ...                     ...             ...              ...           ...
# 3395                   4118              32             37.0    09-07-2023
# 3396                   4056              34            176.0    16-03-2023
# 3397                   3991              22            110.0    03-10-2022
# 3398                   4042              30            128.0    01-01-2023
# 3399                   4001               0            115.0    22-03-2023
#
#       Review Rating  Payment Method     Pur
# ...

# %%
df['Date Purchase'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Date']=df['Date Purchase'].str.split('-').str[0].astype('int')

# %%
df['Month']=df['Date Purchase'].str.split('-').str[1].astype('int')

# %%
df['Year']=df['Date Purchase'].str.split('-').str[2].astype('int')

# %%
df
# Out:
#       Customer Reference ID  Item Purchased  Purchase Amount Date Purchase  \
# 0                      4018              13            295.0    05-02-2023
# 1                      4115              46            295.0    11-07-2023
# 2                      4019              42            295.0    23-03-2023
# 3                      4097              20            295.0    15-03-2023
# 4                      3997              49            295.0    27-11-2022
# ...                     ...             ...              ...           ...
# 3395                   4118              32             37.0    09-07-2023
# 3396                   4056              34            176.0    16-03-2023
# 3397                   3991              22            110.0    03-10-2022
# 3398                   4042              30            128.0    01-01-2023
# 3399                   4001               0            115.0    22-03-2023
#
#       Review Rating  Payment Method     Pur  Date  Month  Year
# ...

# %%
df.drop('Date Purchase', axis=1, inplace=True)

# %%
df
# Out:
#       Customer Reference ID  Item Purchased  Purchase Amount  Review Rating  \
# 0                      4018              13            295.0       2.999057
# 1                      4115              46            295.0       2.000000
# 2                      4019              42            295.0       4.100000
# 3                      4097              20            295.0       3.200000
# 4                      3997              49            295.0       4.700000
# ...                     ...             ...              ...            ...
# 3395                   4118              32             37.0       2.700000
# 3396                   4056              34            176.0       2.500000
# 3397                   3991              22            110.0       2.400000
# 3398                   4042              30            128.0       1.800000
# 3399                   4001               0            115.0       1.400000
#
#       Payment Method  Date  Month  Year
# ...

# %%
df.drop('Pur', axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
df['Purchase Amount Scaled']=scale.fit_transform(df[['Purchase Amount']])

# %%
df['Purchase Amount'].astype('int')
# Out:
# 0       295
# 1       295
# 2       295
# 3       295
# 4       295
#        ...
# 3395     37
# 3396    176
# 3397    110
# 3398    128
# 3399    115
# Name: Purchase Amount, Length: 3400, dtype: int64

# %%
df.describe()
# Out:
#        Customer Reference ID  Item Purchased  Purchase Amount  Review Rating  \
# count            3400.000000     3400.000000      3400.000000    3400.000000
# mean             4039.660588       24.510588       109.407353       2.999057
# std                48.122583       14.491759        53.624299       1.100005
# min              3957.000000        0.000000        10.000000       1.000000
# 25%              3997.000000       12.000000        70.000000       2.100000
# 50%              4040.000000       25.000000       110.000000       2.999057
# 75%              4081.000000       37.000000       146.000000       3.900000
# max              4122.000000       49.000000       295.000000       5.000000
#
#        Payment Method         Date        Month         Year  \
# count     3400.000000  3400.000000  3400.000000  3400.000000
# mean         0.520588    15.698235     6.515588  2022.749118
# std          0.499649     8.822102     3.437637     0.433585
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Customer Reference ID  Item Purchased  Purchase Amount  Review Rating  \
# 0                      4018              13            295.0       2.999057
# 1                      4115              46            295.0       2.000000
# 2                      4019              42            295.0       4.100000
# 3                      4097              20            295.0       3.200000
# 4                      3997              49            295.0       4.700000
# ...                     ...             ...              ...            ...
# 3395                   4118              32             37.0       2.700000
# 3396                   4056              34            176.0       2.500000
# 3397                   3991              22            110.0       2.400000
# 3398                   4042              30            128.0       1.800000
# 3399                   4001               0            115.0       1.400000
#
# ...
